# %%
import numpy as np
import yfinance as yf
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
stocks = [
    "AAPL", "MSFT", "AMZN", "GOOG", "TSLA", "NFLX", "NVDA", "META", "ORCL", "IBM",
    "INTC", "AMD", "QCOM", "ADBE", "CSCO", "CRM", "PYPL", "SAP", "UBER", "LYFT",
    "PEP", "COST", "AVGO", "INTU", "TXN", "TMUS", "GILD", "CHTR", "AMGN", "ISRG",
    "BKNG", "ADP", "MRVL", "WDAY", "SNPS", "PANW", "LRCX", "REGN", "MU", "KLAC",
    "ASML", "ZS", "TEAM", "ZM", "DOCU", "OKTA", "CRWD", "SHOP", "DDOG", "MDB"
]

excluded_stocks = []

def fetch_options_data(stock):
    print(f"\nFetching options data for {stock}...")
    ticker = yf.Ticker(stock)

    # Try to get spot price early to use consistently
    try:
        spot_price = ticker.info.get("regularMarketPrice")
        if spot_price is None or np.isnan(spot_price):
            raise ValueError("Spot price unavailable")
        print(f"  - Spot Price: {spot_price}")
    except Exception as e:
        print(f"  - Failed to fetch spot price for {stock}: {e}")
        return pd.DataFrame()

    try:
        expiration_dates = ticker.options
        if not expiration_dates:
            print(f"  - No expiration dates available for {stock}. Skipping.")
            return pd.DataFrame()
    except Exception as e:
        print(f"  - Failed to fetch expiration dates for {stock}: {e}")
        return pd.DataFrame()

    all_data = []
    for exp_date in expiration_dates:
        try:
            options_chain = ticker.option_chain(exp_date)

            # Fetch and label calls and puts
            calls = options_chain.calls.copy()
            calls['option_type'] = 'call'
            calls['expiration_date'] = exp_date
            calls['stock'] = stock

            puts = options_chain.puts.copy()
            puts['option_type'] = 'put'
            puts['expiration_date'] = exp_date
            puts['stock'] = stock

            # Combine
            combined = pd.concat([calls, puts], ignore_index=True)
            combined['spot_price'] = spot_price  # Assign spot price to every row
            all_data.append(combined)

            print(f"  - Fetched data for expiration date: {exp_date}")
        except Exception as e:
            print(f"  - Failed to fetch data for expiration {exp_date}: {e}")

    return pd.concat(all_data, ignore_index=True) if all_data else pd.DataFrame()

def fetch_with_retries(stock, retries=3):
    print(f"\n=== Fetching Data for {stock} with Retry Mechanism ===")
    for attempt in range(retries):
        try:
            print(f"  Attempt {attempt + 1} of {retries}...")
            data = fetch_options_data(stock)
            if not data.empty:
                print(f"  Successfully fetched data for {stock}.")
                return data
        except Exception as e:
            print(f"  Error during attempt {attempt + 1}: {e}")
    print(f"Failed to fetch data for {stock} after {retries} attempts.")
    return pd.DataFrame()

# Fetch data for all stocks
print("\n=== Starting Data Fetch for All Stocks ===")
all_options_data = []

for stock in stocks:
    data = fetch_with_retries(stock)
    if not data.empty:
        all_options_data.append(data)
    else:
        excluded_stocks.append(stock)

# Combine results
if all_options_data:
    options_data = pd.concat(all_options_data, ignore_index=True)
    print(f"\n=== Data Fetch Complete ===")
    print(f"  Total Data Points Collected: {options_data.shape[0]}")
    print(f"  Stocks Excluded: {len(excluded_stocks)}")
    if excluded_stocks:
        print(f"    Excluded Stocks: {', '.join(excluded_stocks)}")
else:
    print("\nNo data fetched!")
# Out:
# === Starting Data Fetch for All Stocks ===
#
# === Fetching Data for AAPL with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for AAPL...
#   - Spot Price: 202.3216
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for AAPL.
#
# === Fetching Data for MSFT with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for MSFT...
#   - Spot Price: 497.88
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for MSFT.
#
# === Fetching Data for AMZN with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for AMZN...
#   - Spot Price: 219.3435
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for AMZN.
#
# === Fetching Data for GOOG with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for GOOG...
#   - Spot Price: 174.27
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for GOOG.
#
# === Fetching Data for TSLA with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for TSLA...
#   - Spot Price: 324.6925
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for TSLA.
#
# === Fetching Data for NFLX with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for NFLX...
#   - Spot Price: 1321.3484
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for NFLX.
#
# === Fetching Data for NVDA with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for NVDA...
#   - Spot Price: 157.64
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for NVDA.
#
# === Fetching Data for META with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for META...
#   - Spot Price: 730.415
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for META.
#
# === Fetching Data for ORCL with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for ORCL...
#   - Spot Price: 213.775
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   Successfully fetched data for ORCL.
#
# === Fetching Data for IBM with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for IBM...
#   - Spot Price: 291.19
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for IBM.
#
# === Fetching Data for INTC with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for INTC...
#   - Spot Price: 22.685
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for INTC.
#
# === Fetching Data for AMD with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for AMD...
#   - Spot Price: 143.64
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for AMD.
#
# === Fetching Data for QCOM with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for QCOM...
#   - Spot Price: 158.85
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for QCOM.
#
# === Fetching Data for ADBE with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for ADBE...
#   - Spot Price: 388.905
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for ADBE.
#
# === Fetching Data for CSCO with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for CSCO...
#   - Spot Price: 68.97
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for CSCO.
#
# === Fetching Data for CRM with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for CRM...
#   - Spot Price: 272.85
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for CRM.
#
# === Fetching Data for PYPL with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for PYPL...
#   - Spot Price: 73.215
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for PYPL.
#
# === Fetching Data for SAP with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for SAP...
#   - Spot Price: 302.72
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for SAP.
#
# === Fetching Data for UBER with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for UBER...
#   - Spot Price: 91.34
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for UBER.
#
# === Fetching Data for LYFT with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for LYFT...
#   - Spot Price: 15.545
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for LYFT.
#
# === Fetching Data for PEP with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for PEP...
#   - Spot Price: 130.6
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for PEP.
#
# === Fetching Data for COST with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for COST...
#   - Spot Price: 990.935
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for COST.
#
# === Fetching Data for AVGO with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for AVGO...
#   - Spot Price: 270.045
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for AVGO.
#
# === Fetching Data for INTU with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for INTU...
#   - Spot Price: 784.14
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for INTU.
#
# === Fetching Data for TXN with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for TXN...
#   - Spot Price: 206.93
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for TXN.
#
# === Fetching Data for TMUS with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for TMUS...
#   - Spot Price: 235.395
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for TMUS.
#
# === Fetching Data for GILD with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for GILD...
#   - Spot Price: 110.6
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for GILD.
#
# === Fetching Data for CHTR with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for CHTR...
#   - Spot Price: 399.43
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for CHTR.
#
# === Fetching Data for AMGN with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for AMGN...
#   - Spot Price: 279.575
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for AMGN.
#
# === Fetching Data for ISRG with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for ISRG...
#   - Spot Price: 542.055
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for ISRG.
#
# === Fetching Data for BKNG with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for BKNG...
#   - Spot Price: 5693.81
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-09-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for BKNG.
#
# === Fetching Data for ADP with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for ADP...
#   - Spot Price: 304.45
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for ADP.
#
# === Fetching Data for MRVL with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for MRVL...
#   - Spot Price: 77.455
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   Successfully fetched data for MRVL.
#
# === Fetching Data for WDAY with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for WDAY...
#   - Spot Price: 238.675
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   Successfully fetched data for WDAY.
#
# === Fetching Data for SNPS with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for SNPS...
#   - Spot Price: 510.0
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for SNPS.
#
# === Fetching Data for PANW with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for PANW...
#   - Spot Price: 201.325
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for PANW.
#
# === Fetching Data for LRCX with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for LRCX...
#   - Spot Price: 97.35
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for LRCX.
#
# === Fetching Data for REGN with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for REGN...
#   - Spot Price: 523.16
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   Successfully fetched data for REGN.
#
# === Fetching Data for MU with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for MU...
#   - Spot Price: 124.4112
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-05-15
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for MU.
#
# === Fetching Data for KLAC with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for KLAC...
#   - Spot Price: 897.45
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for KLAC.
#
# === Fetching Data for ASML with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for ASML...
#   - Spot Price: 797.23
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-06-17
#   Successfully fetched data for ASML.
#
# === Fetching Data for ZS with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for ZS...
#   - Spot Price: 316.49
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for ZS.
#
# === Fetching Data for TEAM with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for TEAM...
#   - Spot Price: 206.3175
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for TEAM.
#
# === Fetching Data for ZM with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for ZM...
#   - Spot Price: 78.03
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for ZM.
#
# === Fetching Data for DOCU with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for DOCU...
#   - Spot Price: 76.67
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for DOCU.
#
# === Fetching Data for OKTA with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for OKTA...
#   - Spot Price: 98.82
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for OKTA.
#
# === Fetching Data for CRWD with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for CRWD...
#   - Spot Price: 503.55
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for CRWD.
#
# === Fetching Data for SHOP with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for SHOP...
#   - Spot Price: 114.79
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for SHOP.
#
# === Fetching Data for DDOG with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for DDOG...
#   - Spot Price: 133.0575
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-10-17
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   Successfully fetched data for DDOG.
#
# === Fetching Data for MDB with Retry Mechanism ===
#   Attempt 1 of 3...
#
# Fetching options data for MDB...
#   - Spot Price: 208.815
#   - Fetched data for expiration date: 2025-06-27
#   - Fetched data for expiration date: 2025-07-03
#   - Fetched data for expiration date: 2025-07-11
#   - Fetched data for expiration date: 2025-07-18
#   - Fetched data for expiration date: 2025-07-25
#   - Fetched data for expiration date: 2025-08-01
#   - Fetched data for expiration date: 2025-08-15
#   - Fetched data for expiration date: 2025-09-19
#   - Fetched data for expiration date: 2025-11-21
#   - Fetched data for expiration date: 2025-12-19
#   - Fetched data for expiration date: 2026-01-16
#   - Fetched data for expiration date: 2026-02-20
#   - Fetched data for expiration date: 2026-03-20
#   - Fetched data for expiration date: 2026-06-18
#   - Fetched data for expiration date: 2026-09-18
#   - Fetched data for expiration date: 2026-12-18
#   - Fetched data for expiration date: 2027-01-15
#   - Fetched data for expiration date: 2027-12-17
#   Successfully fetched data for MDB.
#
# === Data Fetch Complete ===
#   Total Data Points Collected: 76782
#   Stocks Excluded: 0

# %%
options_data
# Out:
#             contractSymbol             lastTradeDate  strike  lastPrice  \
# 0      AAPL250627C00110000 2025-06-27 15:59:36+00:00   110.0      91.90
# 1      AAPL250627C00120000 2025-06-20 18:22:00+00:00   120.0      80.40
# 2      AAPL250627C00130000 2025-06-04 19:34:09+00:00   130.0      73.60
# 3      AAPL250627C00135000 2025-06-12 17:20:36+00:00   135.0      64.72
# 4      AAPL250627C00140000 2025-06-25 19:18:58+00:00   140.0      61.20
# ...                    ...                       ...     ...        ...
# 76777   MDB271217P00260000 2025-06-25 16:47:48+00:00   260.0      91.73
# 76778   MDB271217P00270000 2025-05-06 19:09:04+00:00   270.0     123.35
# 76779   MDB271217P00280000 2025-04-21 14:43:28+00:00   280.0     141.19
# 76780   MDB271217P00290000 2025-06-06 18:48:41+00:00   290.0     106.25
# 76781   MDB271217P00330000 2025-06-11 17:46:02+00:00   330.0     141.25
#
#           bid     ask    change  percentChange  volume  openInterest  \
# 0       90.95   92.80  1.440002       1.591867    26.0          55.0
# 1       81.00   82.85  0.000000       0.000000     4.0           4.0
# 2       71.10   72.85  0.000000       0.000000     1.0           0.0
# 3       66.40   67.90  0.000000       0.000000     1.0           2.0
# 4       61.40   62.85  0.000000       0.000000  5561.0        7173.0
# ...       ...     ...       ...            ...     ...           ...
# 76777   87.55   93.15  0.000000       0.000000     4.0           5.0
# 76778   89.65   94.50  0.000000       0.000000     4.0           4.0
# 76779  115.30  121.95  0.000000       0.000000    25.0          52.0
# 76780  109.85  115.05  0.000000       0.000000     1.0          26.0
# 76781  137.80  146.25  1.600006       1.145726     1.0           2.0
#
#        impliedVolatility inTheMoney contractSize currency option_type  \
# 0               6.035159       True      REGULAR      USD        call
# 1               5.359378       True      REGULAR      USD        call
# 2               4.636723       True      REGULAR      USD        call
# 3               4.367192       True      REGULAR      USD        call
# 4               3.962891       True      REGULAR      USD        call
# ...                  ...        ...          ...      ...         ...
# 76777           0.448431       True      REGULAR      USD         put
# 76778           0.401099       True      REGULAR      USD         put
# 76779           0.526433       True      REGULAR      USD         put
# 76780           0.439093       True      REGULAR      USD         put
# 76781           0.426336       True      REGULAR      USD         put
#
#       expiration_date stock  spot_price
# 0          2025-06-27  AAPL    202.3216
# 1          2025-06-27  AAPL    202.3216
# 2          2025-06-27  AAPL    202.3216
# 3          2025-06-27  AAPL    202.3216
# 4          2025-06-27  AAPL    202.3216
# ...               ...   ...         ...
# 76777      2027-12-17   MDB    208.8150
# 76778      2027-12-17   MDB    208.8150
# 76779      2027-12-17   MDB    208.8150
# 76780      2027-12-17   MDB    208.8150
# 76781      2027-12-17   MDB    208.8150
#
# [76782 rows x 18 columns]

# %%
options_data.isna().sum()
# Out:
# contractSymbol          0
# lastTradeDate           0
# strike                  0
# lastPrice               0
# bid                   255
# ask                   161
# change                  0
# percentChange          48
# volume               4931
# openInterest          190
# impliedVolatility       0
# inTheMoney              0
# contractSize            0
# currency                0
# option_type             0
# expiration_date         0
# stock                   0
# spot_price              0
# dtype: int64

# %%
#dealing with NaNs
options_data['openInterest']= options_data['openInterest'].fillna(0)

options_data['volume'] = options_data['volume'].fillna(0)

options_data = options_data.dropna(axis=1)

options_data.isnull().sum()
# Out:
# contractSymbol       0
# lastTradeDate        0
# strike               0
# lastPrice            0
# change               0
# volume               0
# openInterest         0
# impliedVolatility    0
# inTheMoney           0
# contractSize         0
# currency             0
# option_type          0
# expiration_date      0
# stock                0
# spot_price           0
# dtype: int64

# %%
exclude_cols= ['contractSize', 'currency', 'spot_price','contractSymbol']
options_data = options_data.drop(exclude_cols, axis=1)

# %%
options_data["lastTradeDate"] = pd.to_datetime(options_data['lastTradeDate']).dt.date


options_data['stock'] = options_data['stock'].astype("string")
print(options_data.dtypes)
# Out:
# lastTradeDate                object
# strike                      float64
# lastPrice                   float64
# change                      float64
# volume                      float64
# openInterest                float64
# impliedVolatility           float64
# inTheMoney                   object
# option_type                  object
# expiration_date              object
# stock                string[python]
# dtype: object

# %%
options_data['lastTradeDate'] = pd.to_datetime(options_data['lastTradeDate'])
options_data['expiration_date'] = pd.to_datetime(options_data['expiration_date'])
options_data.dtypes
# Out:
# lastTradeDate        datetime64[ns]
# strike                      float64
# lastPrice                   float64
# change                      float64
# volume                      float64
# openInterest                float64
# impliedVolatility           float64
# inTheMoney                   object
# option_type                  object
# expiration_date      datetime64[ns]
# stock                string[python]
# dtype: object

# %%
options_data.set_index(['stock', 'lastTradeDate'], inplace=True)
options_data
# Out:
#                      strike  lastPrice    change  volume  openInterest  \
# stock lastTradeDate
# AAPL  2025-06-27      110.0      91.90  1.440002    26.0          55.0
#       2025-06-20      120.0      80.40  0.000000     4.0           4.0
#       2025-06-04      130.0      73.60  0.000000     1.0           0.0
#       2025-06-12      135.0      64.72  0.000000     1.0           2.0
#       2025-06-25      140.0      61.20  0.000000  5561.0        7173.0
# ...                     ...        ...       ...     ...           ...
# MDB   2025-06-25      260.0      91.73  0.000000     4.0           5.0
#       2025-05-06      270.0     123.35  0.000000     4.0           4.0
#       2025-04-21      280.0     141.19  0.000000    25.0          52.0
#       2025-06-06      290.0     106.25  0.000000     1.0          26.0
#       2025-06-11      330.0     141.25  1.600006     1.0           2.0
#
#                      impliedVolatility inTheMoney option_type expiration_date
# stock lastTradeDate
# AAPL  2025-06-27              6.035159       True        call      2025-06-27
#       2025-06-20              5.359378       True        call      2025-06-27
#       2025-06-04              4.636723       True        call      2025-06-27
#       2025-06-12              4.367192       True        call      2025-06-27
#       2025-06-25              3.962891       True        call      2025-06-27
# ...                                ...        ...         ...             ...
# MDB   2025-06-25              0.448431       True         put      2027-12-17
#       2025-05-06              0.401099       True         put      2027-12-17
#       2025-04-21              0.526433       True         put      2027-12-17
#       2025-06-06              0.439093       True         put      2027-12-17
#       2025-06-11              0.426336       True         put      2027-12-17
#
# [76782 rows x 9 columns]

# %%
options_data.index.get_level_values(level=0)
# Out:
# Index(['AAPL', 'AAPL', 'AAPL', 'AAPL', 'AAPL', 'AAPL', 'AAPL', 'AAPL', 'AAPL',
#        'AAPL',
#        ...
#        'MDB', 'MDB', 'MDB', 'MDB', 'MDB', 'MDB', 'MDB', 'MDB', 'MDB', 'MDB'],
#       dtype='string', name='stock', length=76782)

# %%
def add_spot_price(options_data):
    ticker = options_data['stock']
    print(ticker)
    aapl_hist = yf.Ticker(ticker)
    hist = aapl_hist.history(start = start_date, end = end_date)
    
    hist.rename(columns = {'Close': 'Spot_Price1'}, inplace=True)
    hist.rename(columns = {'Date': 'lastTradeDate'}, inplace=True)
    print(hist)
    hist = hist.reset_index()
    
    hist['Date'] = hist['Date'].dt.tz_localize(None)
    options_data['lastTradeDate'] = pd.to_datetime(options_data['lastTradeDate'])
    
    print(pd.merge(options_data, hist[['Date','Spot_Price1']], how = 'left', left_on='lastTradeDate', right_on='Date'))
    return 
options_data.groupby(level =0, group_keys=False)

# %%
import pandas as pd
import yfinance as yf
from datetime import timedelta
df = options_data
# Ensure proper datatypes
df.reset_index(inplace=True)  # Reset if MultiIndex
df['lastTradeDate'] = pd.to_datetime(df['lastTradeDate'])
df['stock'] = df['stock'].astype(str).str.upper().str.strip()

unique_pairs = df[['stock', 'lastTradeDate']].drop_duplicates()

spot_price_map = {}

for _, row in unique_pairs.iterrows():
    stock = row['stock']
    date = row['lastTradeDate'].date()
    key = (stock, date)

    try:
        ticker = yf.Ticker(stock)
        hist = ticker.history(start=date - timedelta(days=3), end=date + timedelta(days=2))
        hist.index = hist.index.tz_localize(None)  # ← Fix here

        valid_prices = hist.loc[hist.index.normalize() <= pd.to_datetime(date), 'Close']
        if not valid_prices.empty:
            spot_price_map[key] = valid_prices.iloc[-1]
        else:
            spot_price_map[key] = None
    except Exception as e:
        print(f"Failed to fetch for {stock} on {date}: {e}")
        spot_price_map[key] = None

print(spot_price_map)
# Out:
# {('AAPL', datetime.date(2025, 6, 27)): 202.3350067138672, ('AAPL', datetime.date(2025, 6, 20)): 201.0, ('AAPL', datetime.date(2025, 6, 4)): 202.82000732421875, ('AAPL', datetime.date(2025, 6, 12)): 199.1999969482422, ('AAPL', datetime.date(2025, 6, 25)): 201.55999755859375, ('AAPL', datetime.date(2025, 6, 26)): 201.0, ('AAPL', datetime.date(2025, 6, 13)): 196.4499969482422, ('AAPL', datetime.date(2025, 6, 24)): 200.3000030517578, ('AAPL', datetime.date(2025, 6, 23)): 201.5, ('AAPL', datetime.date(2025, 6, 10)): 202.6699981689453, ('AAPL', datetime.date(2025, 5, 28)): 200.4199981689453, ('AAPL', datetime.date(2025, 5, 27)): 200.2100067138672, ('AAPL', datetime.date(2025, 5, 29)): 199.9499969482422, ('AAPL', datetime.date(2025, 6, 16)): 198.4199981689453, ('AAPL', datetime.date(2025, 6, 9)): 201.4499969482422, ('AAPL', datetime.date(2025, 5, 30)): 200.85000610351562, ('AAPL', datetime.date(2025, 6, 11)): 198.77999877929688, ('AAPL', datetime.date(2025, 6, 18)): 196.5800018310547, ('AAPL', datetime.date(2025, 6, 6)): 203.9199981689453, ('AAPL', datetime.date(2025, 6, 17)): 195.63999938964844, ('AAPL', datetime.date(2025, 6, 5)): 200.6300048828125, ('AAPL', datetime.date(2025, 5, 5)): 198.62953186035156, ('AAPL', datetime.date(2025, 5, 2)): 205.08106994628906, ('AAPL', datetime.date(2025, 4, 14)): 202.25477600097656, ('AAPL', datetime.date(2025, 4, 3)): 202.9239044189453, ('AAPL', datetime.date(2025, 2, 3)): 227.46128845214844, ('AAPL', datetime.date(2025, 3, 5)): 235.4312744140625, ('AAPL', datetime.date(2024, 12, 27)): 254.9749298095703, ('AAPL', datetime.date(2025, 5, 14)): 212.3300018310547, ('AAPL', datetime.date(2025, 1, 10)): 236.280029296875, ('AAPL', datetime.date(2025, 4, 8)): 172.19419860839844, ('AAPL', datetime.date(2025, 5, 15)): 211.4499969482422, ('AAPL', datetime.date(2025, 5, 22)): 201.36000061035156, ('AAPL', datetime.date(2025, 2, 24)): 246.77639770507812, ('AAPL', datetime.date(2025, 4, 1)): 222.897705078125, ('AAPL', datetime.date(2024, 12, 20)): 253.87759399414062, ('AAPL', datetime.date(2024, 8, 13)): 220.4949493408203, ('AAPL', datetime.date(2025, 4, 15)): 201.87527465820312, ('AAPL', datetime.date(2025, 4, 30)): 212.22171020507812, ('AAPL', datetime.date(2025, 4, 29)): 210.9333953857422, ('AAPL', datetime.date(2025, 5, 21)): 202.08999633789062, ('AAPL', datetime.date(2025, 5, 8)): 197.2313690185547, ('AAPL', datetime.date(2025, 5, 1)): 213.04063415527344, ('AAPL', datetime.date(2025, 4, 7)): 181.2223663330078, ('AAPL', datetime.date(2025, 6, 2)): 201.6999969482422, ('AAPL', datetime.date(2025, 3, 7)): 238.7569122314453, ('AAPL', datetime.date(2024, 12, 19)): 249.1888885498047, ('AAPL', datetime.date(2025, 3, 18)): 212.4114532470703, ('AAPL', datetime.date(2024, 11, 22)): 229.3168182373047, ('AAPL', datetime.date(2024, 11, 8)): 226.41383361816406, ('AAPL', datetime.date(2025, 5, 23)): 195.27000427246094, ('AAPL', datetime.date(2025, 5, 19)): 208.77999877929688, ('AAPL', datetime.date(2025, 3, 19)): 214.95811462402344, ('AAPL', datetime.date(2025, 3, 10)): 227.1820831298828, ('AAPL', datetime.date(2025, 3, 4)): 235.6210174560547, ('AAPL', datetime.date(2025, 2, 26)): 240.0452117919922, ('AAPL', datetime.date(2025, 4, 11)): 197.89048767089844, ('AAPL', datetime.date(2025, 6, 3)): 203.27000427246094, ('AAPL', datetime.date(2025, 2, 25)): 246.71646118164062, ('AAPL', datetime.date(2025, 5, 16)): 211.25999450683594, ('AAPL', datetime.date(2025, 5, 6)): 198.25001525878906, ('AAPL', datetime.date(2025, 5, 13)): 212.92999267578125, ('AAPL', datetime.date(2025, 4, 21)): 192.9070281982422, ('AAPL', datetime.date(2025, 4, 4)): 188.13330078125, ('AAPL', datetime.date(2025, 4, 9)): 198.58958435058594, ('AAPL', datetime.date(2025, 4, 25)): 209.00592041015625, ('AAPL', datetime.date(2025, 2, 14)): 244.2796630859375, ('AAPL', datetime.date(2025, 5, 7)): 195.99298095703125, ('AAPL', datetime.date(2025, 5, 9)): 198.27000427246094, ('AAPL', datetime.date(2025, 4, 16)): 194.0155792236328, ('AAPL', datetime.date(2025, 5, 12)): ...

# %%
df['spot_price'] = df.apply(
    lambda row: spot_price_map.get((row['stock'], row['lastTradeDate'].date())), axis=1
)

# %%
df
# Out:
#       stock lastTradeDate  strike  lastPrice    change  volume  openInterest  \
# 0      AAPL    2025-06-27   110.0      91.90  1.440002    26.0          55.0
# 1      AAPL    2025-06-20   120.0      80.40  0.000000     4.0           4.0
# 2      AAPL    2025-06-04   130.0      73.60  0.000000     1.0           0.0
# 3      AAPL    2025-06-12   135.0      64.72  0.000000     1.0           2.0
# 4      AAPL    2025-06-25   140.0      61.20  0.000000  5561.0        7173.0
# ...     ...           ...     ...        ...       ...     ...           ...
# 76777   MDB    2025-06-25   260.0      91.73  0.000000     4.0           5.0
# 76778   MDB    2025-05-06   270.0     123.35  0.000000     4.0           4.0
# 76779   MDB    2025-04-21   280.0     141.19  0.000000    25.0          52.0
# 76780   MDB    2025-06-06   290.0     106.25  0.000000     1.0          26.0
# 76781   MDB    2025-06-11   330.0     141.25  1.600006     1.0           2.0
#
#        impliedVolatility inTheMoney option_type expiration_date  spot_price
# 0               6.035159       True        call      2025-06-27  202.335007
# 1               5.359378       True        call      2025-06-27  201.000000
# 2               4.636723       True        call      2025-06-27  202.820007
# 3               4.367192       True        call      2025-06-27  199.199997
# 4               3.962891       True        call      2025-06-27  201.559998
# ...                  ...        ...         ...             ...         ...
# 76777           0.448431       True         put      2027-12-17  206.759995
# 76778           0.401099       True         put      2027-12-17  172.220001
# 76779           0.526433       True         put      2027-12-17  151.669998
# 76780           0.439093       True         put      2027-12-17  220.139999
# 76781           0.426336       True         put      2027-12-17  210.600006
#
# [76782 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# stock                0
# lastTradeDate        0
# strike               0
# lastPrice            0
# change               0
# volume               0
# openInterest         0
# impliedVolatility    0
# inTheMoney           0
# option_type          0
# expiration_date      0
# spot_price           0
# dtype: int64

# %%
import pandas_datareader.data as web
import datetime

# Define your date range
start = df['expiration_date'].min() - pd.Timedelta(days=7)
end = df['expiration_date'].max() + pd.Timedelta(days=7)

# Fetch from FRED: DTB3 is 3-month T-Bill rate (annualized)
rfr_data = web.DataReader("DTB3", "fred", start, end).ffill()


# Ensure expiration_date is datetime
df['expiration_date'] = pd.to_datetime(df['expiration_date'])

# Map RFR (convert from % to decimal)
df['risk_free_rate'] = df['expiration_date'].map(
    lambda d: rfr_data.asof(pd.Timestamp(d)).values[0] / 100
)

# %%
df
# Out:
#       stock lastTradeDate  strike  lastPrice    change  volume  openInterest  \
# 0      AAPL    2025-06-27   110.0      91.90  1.440002    26.0          55.0
# 1      AAPL    2025-06-20   120.0      80.40  0.000000     4.0           4.0
# 2      AAPL    2025-06-04   130.0      73.60  0.000000     1.0           0.0
# 3      AAPL    2025-06-12   135.0      64.72  0.000000     1.0           2.0
# 4      AAPL    2025-06-25   140.0      61.20  0.000000  5561.0        7173.0
# ...     ...           ...     ...        ...       ...     ...           ...
# 76777   MDB    2025-06-25   260.0      91.73  0.000000     4.0           5.0
# 76778   MDB    2025-05-06   270.0     123.35  0.000000     4.0           4.0
# 76779   MDB    2025-04-21   280.0     141.19  0.000000    25.0          52.0
# 76780   MDB    2025-06-06   290.0     106.25  0.000000     1.0          26.0
# 76781   MDB    2025-06-11   330.0     141.25  1.600006     1.0           2.0
#
#        impliedVolatility inTheMoney option_type expiration_date  spot_price  \
# 0               6.035159       True        call      2025-06-27  202.335007
# 1               5.359378       True        call      2025-06-27  201.000000
# 2               4.636723       True        call      2025-06-27  202.820007
# 3               4.367192       True        call      2025-06-27  199.199997
# 4               3.962891       True        call      2025-06-27  201.559998
# ...                  ...        ...         ...             ...         ...
# 76777           0.448431       True         put      2027-12-17  206.759995
# 76778           0.401099       True         put      2027-12-17  172.220001
# 76779           0.526433       True         put      2027-12-17  151.669998
# 76780           0.439093       True         put      2027-12-17  220.139999
# 76781           0.426336       True         put      2027-12-17  210.600006
#
#        risk_free_rate
# 0              0.0419
# 1              0.0419
# 2              0.0419
# 3              0.0419
# 4              0.0419
# ...               ...
# 76777          0.0419
# 76778          0.0419
# 76779          0.0419
# 76780          0.0419
# 76781          0.0419
#
# [76782 rows x 13 columns]

# %%
from scipy.stats import norm

def calculate_greeks(S, K, T, r, sigma, option_type='call'):
    if T <= 0 or sigma <= 0:
        return {'Delta': np.nan, 'Gamma': np.nan, 'Vega': np.nan, 'Theta': np.nan, 'Rho': np.nan}

    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)

    delta = norm.cdf(d1) if option_type == 'call' else norm.cdf(d1) - 1
    gamma = norm.pdf(d1) / (S * sigma * np.sqrt(T))
    vega = S * norm.pdf(d1) * np.sqrt(T) / 100
    theta_call = (-S * norm.pdf(d1) * sigma / (2 * np.sqrt(T)) -
                  r * K * np.exp(-r * T) * norm.cdf(d2)) / 365
    theta_put = (-S * norm.pdf(d1) * sigma / (2 * np.sqrt(T)) +
                 r * K * np.exp(-r * T) * norm.cdf(-d2)) / 365
    rho_call = K * T * np.exp(-r * T) * norm.cdf(d2) / 100
    rho_put = -K * T * np.exp(-r * T) * norm.cdf(-d2) / 100

    theta = theta_call if option_type == 'call' else theta_put
    rho = rho_call if option_type == 'call' else rho_put
    return {
        'Delta': delta,
        'Gamma': gamma,
        'Vega': vega,
        'Theta': theta,
        'Rho': rho
    }


                        
from datetime import datetime
today = datetime.today() 
print(today)
greeks = df.apply(lambda row: pd.Series(
    calculate_greeks(
        S=row['spot_price'], K=row['strike'], T=(row['expiration_date']-today).days/365, r=row['risk_free_rate'],
        sigma=row['impliedVolatility'],
        option_type=row['option_type']
    )), axis=1)

df = pd.concat([df, greeks], axis=1)
    


#df_all_options = fetch_options_and_greeks(tickers, max_expiries=3)

#print(f"Fetched {df_all_options.shape[0]} options.")
df.head()
# Out:
# 2025-06-27 23:06:51.781729
#   stock lastTradeDate  strike  lastPrice    change  volume  openInterest  \
# 0  AAPL    2025-06-27   110.0      91.90  1.440002    26.0          55.0
# 1  AAPL    2025-06-20   120.0      80.40  0.000000     4.0           4.0
# 2  AAPL    2025-06-04   130.0      73.60  0.000000     1.0           0.0
# 3  AAPL    2025-06-12   135.0      64.72  0.000000     1.0           2.0
# 4  AAPL    2025-06-25   140.0      61.20  0.000000  5561.0        7173.0
#
#    impliedVolatility inTheMoney option_type expiration_date  spot_price  \
# 0           6.035159       True        call      2025-06-27  202.335007
# 1           5.359378       True        call      2025-06-27  201.000000
# 2           4.636723       True        call      2025-06-27  202.820007
# 3           4.367192       True        call      2025-06-27  199.199997
# 4           3.962891       True        call      2025-06-27  201.559998
#
#    risk_free_rate  Delta  Gamma  Vega  Theta  Rho
# 0          0.0419    NaN    NaN   NaN    NaN  NaN
# 1          0.0419    NaN    NaN   NaN    NaN  NaN
# 2          0.0419    NaN    NaN   NaN    NaN  NaN
# 3          0.0419    NaN    NaN   NaN    NaN  NaN
# 4          0.0419    NaN    NaN   NaN    NaN  NaN

# %%
df
# Out:
#       stock lastTradeDate  strike  lastPrice    change  volume  openInterest  \
# 0      AAPL    2025-06-27   110.0      91.90  1.440002    26.0          55.0
# 1      AAPL    2025-06-20   120.0      80.40  0.000000     4.0           4.0
# 2      AAPL    2025-06-04   130.0      73.60  0.000000     1.0           0.0
# 3      AAPL    2025-06-12   135.0      64.72  0.000000     1.0           2.0
# 4      AAPL    2025-06-25   140.0      61.20  0.000000  5561.0        7173.0
# ...     ...           ...     ...        ...       ...     ...           ...
# 76777   MDB    2025-06-25   260.0      91.73  0.000000     4.0           5.0
# 76778   MDB    2025-05-06   270.0     123.35  0.000000     4.0           4.0
# 76779   MDB    2025-04-21   280.0     141.19  0.000000    25.0          52.0
# 76780   MDB    2025-06-06   290.0     106.25  0.000000     1.0          26.0
# 76781   MDB    2025-06-11   330.0     141.25  1.600006     1.0           2.0
#
#        impliedVolatility inTheMoney option_type expiration_date  spot_price  \
# 0               6.035159       True        call      2025-06-27  202.335007
# 1               5.359378       True        call      2025-06-27  201.000000
# 2               4.636723       True        call      2025-06-27  202.820007
# 3               4.367192       True        call      2025-06-27  199.199997
# 4               3.962891       True        call      2025-06-27  201.559998
# ...                  ...        ...         ...             ...         ...
# 76777           0.448431       True         put      2027-12-17  206.759995
# 76778           0.401099       True         put      2027-12-17  172.220001
# 76779           0.526433       True         put      2027-12-17  151.669998
# 76780           0.439093       True         put      2027-12-17  220.139999
# 76781           0.426336       True         put      2027-12-17  210.600006
#
#        risk_free_rate     Delta     Gamma      Vega     Theta       Rho
# 0              0.0419       NaN       NaN       NaN       NaN       NaN
# 1              0.0419       NaN       NaN       NaN       NaN       NaN
# 2              0.0419       NaN       NaN       NaN       NaN       NaN
# 3              0.0419       NaN       NaN       NaN       NaN       NaN
# 4              0.0419       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# 76777          0.0419 -0.430803  0.002696  1.277127 -0.012851 -4.067724
# 76778          0.0419 -0.592368  0.003575  1.050986 -0.000836 -4.850432
# 76779          0.0419 -0.580014  0.003114  0.931992 -0.002610 -5.292866
# 76780          0.0419 -0.461822  0.002613  1.374267 -0.011722 -4.677473
# 76781          0.0419 -0.571635  0.002781  1.299414 -0.003297 -5.901033
#
# [76782 rows x 18 columns]

# %%
greeks_df = pd.DataFrame(greeks)
greeks_df
df.dtypes
# Out:
# stock                        object
# lastTradeDate        datetime64[ns]
# strike                      float64
# lastPrice                   float64
# change                      float64
# volume                      float64
# openInterest                float64
# impliedVolatility           float64
# inTheMoney                   object
# option_type                  object
# expiration_date      datetime64[ns]
# spot_price                  float64
# risk_free_rate              float64
# Delta                       float64
# Gamma                       float64
# Vega                        float64
# Theta                       float64
# Rho                         float64
# dtype: object

# %%
# Add time to expiry

today = datetime.today()

df['time_to_expiry'] = df.apply(lambda row: (row['expiration_date'] - today).days / 365, axis =1)

# Add moneyness
df["moneyness"] = df.apply(lambda row: row['spot_price'] / row["strike"], axis=1)

# Clean up
df = df.dropna()

# %%
df.set_index('stock', inplace=True)
df_encoded = pd.get_dummies(df, 'option_type')
df_encoded
# Out:
#       lastTradeDate  strike  lastPrice    change  volume  openInterest  \
# stock
# AAPL     2025-06-27   110.0      91.80  0.800003    40.0         418.0
# AAPL     2025-06-26   140.0      61.36  0.000000     3.0        1913.0
# AAPL     2025-06-20   145.0      53.74  0.000000    11.0          70.0
# AAPL     2025-06-26   150.0      50.10  0.000000    10.0          14.0
# AAPL     2025-06-20   155.0      43.55  0.000000     1.0           1.0
# ...             ...     ...        ...       ...     ...           ...
# MDB      2025-06-25   260.0      91.73  0.000000     4.0           5.0
# MDB      2025-05-06   270.0     123.35  0.000000     4.0           4.0
# MDB      2025-04-21   280.0     141.19  0.000000    25.0          52.0
# MDB      2025-06-06   290.0     106.25  0.000000     1.0          26.0
# MDB      2025-06-11   330.0     141.25  1.600006     1.0           2.0
#
#        impliedVolatility expiration_date  spot_price  risk_free_rate  ...  \
# stock                                                                 ...
# AAPL            1.593752      2025-07-03  202.335007          0.0419  ...
# AAPL            1.197270      2025-07-03  201.000000          0.0419  ...
# AAPL            1.294925      2025-07-03  201.000000          0.0419  ...
# AAPL            1.181645      2025-07-03  201.000000          0.0419  ...
# AAPL            1.015630      2025-07-03  201.000000          0.0419  ...
# ...                  ...             ...         ...             ...  ...
# MDB             0.448431      2027-12-17  206.759995          0.0419  ...
# MDB             0.401099      2027-12-17  172.220001          0.0419  ...
# MDB             0.526433      2027-12-17  151.669998          0.0419  ...
# MDB             0.439093      2027-12-17  220.139999          0.0419  ...
# MDB             0.426336      2027-12-17  210.600006          0.0419  ...
#
#           Gamma      Vega     Theta       Rho  time_to_expiry  moneyness  \
# stock
# AAPL   0.000037  0.000330 -0.017872  0.015049        0.013699   1.839409
# AAPL   0.000417  0.002765 -0.049070  0.019053        0.013699   1.435714
# AAPL   0.001079  0.007734 -0.116479  0.019482        0.013699   1.386207
# AAPL   0.001306  0.008540 -0.117781  0.020123        0.013699   1.340000
# AAPL   0.001327  0.007458 -0.093238  0.020870        0.013699   1.296774
# ...         ...       ...       ...       ...             ...        ...
# MDB    0.002696  1.277127 -0.012851 -4.067724        2.471233   0.795231
# MDB    0.003575  1.050986 -0.000836 -4.850432        2.471233   0.637852
# MDB    0.003114  0.931992 -0.002610 -5.292866        2.471233   0.541679
# MDB    0.002613  1.374267 -0.011722 -4.677473        2.471233   0.759103
# MDB    0.002781  1.299414 -0.003297 -5.901033        2.471233   0.638182
#
#        option_type_False  option_type_True  option_type_call  option_type_put
# stock
# AAPL               False              True              True            False
# AAPL               False              True              True            False
# AAPL               False              True              True            False
# AAPL               False              True              True            False
# AAPL               False              True              True            False
# ...                  ...               ...               ...              ...
# MDB                False              True             False             True
# MDB                False              True             False             True
# MDB                False              True             False             True
# MDB                False              True             False             True
# MDB                False              True             False             True
#
# [70662 rows x 21 columns]

# %%
df_encoded.dropna()
# Out:
#       lastTradeDate  strike  lastPrice    change  volume  openInterest  \
# stock
# AAPL     2025-06-27   110.0      91.80  0.800003    40.0         418.0
# AAPL     2025-06-26   140.0      61.36  0.000000     3.0        1913.0
# AAPL     2025-06-20   145.0      53.74  0.000000    11.0          70.0
# AAPL     2025-06-26   150.0      50.10  0.000000    10.0          14.0
# AAPL     2025-06-20   155.0      43.55  0.000000     1.0           1.0
# ...             ...     ...        ...       ...     ...           ...
# MDB      2025-06-25   260.0      91.73  0.000000     4.0           5.0
# MDB      2025-05-06   270.0     123.35  0.000000     4.0           4.0
# MDB      2025-04-21   280.0     141.19  0.000000    25.0          52.0
# MDB      2025-06-06   290.0     106.25  0.000000     1.0          26.0
# MDB      2025-06-11   330.0     141.25  1.600006     1.0           2.0
#
#        impliedVolatility expiration_date  spot_price  risk_free_rate  ...  \
# stock                                                                 ...
# AAPL            1.593752      2025-07-03  202.335007          0.0419  ...
# AAPL            1.197270      2025-07-03  201.000000          0.0419  ...
# AAPL            1.294925      2025-07-03  201.000000          0.0419  ...
# AAPL            1.181645      2025-07-03  201.000000          0.0419  ...
# AAPL            1.015630      2025-07-03  201.000000          0.0419  ...
# ...                  ...             ...         ...             ...  ...
# MDB             0.448431      2027-12-17  206.759995          0.0419  ...
# MDB             0.401099      2027-12-17  172.220001          0.0419  ...
# MDB             0.526433      2027-12-17  151.669998          0.0419  ...
# MDB             0.439093      2027-12-17  220.139999          0.0419  ...
# MDB             0.426336      2027-12-17  210.600006          0.0419  ...
#
#           Gamma      Vega     Theta       Rho  time_to_expiry  moneyness  \
# stock
# AAPL   0.000037  0.000330 -0.017872  0.015049        0.013699   1.839409
# AAPL   0.000417  0.002765 -0.049070  0.019053        0.013699   1.435714
# AAPL   0.001079  0.007734 -0.116479  0.019482        0.013699   1.386207
# AAPL   0.001306  0.008540 -0.117781  0.020123        0.013699   1.340000
# AAPL   0.001327  0.007458 -0.093238  0.020870        0.013699   1.296774
# ...         ...       ...       ...       ...             ...        ...
# MDB    0.002696  1.277127 -0.012851 -4.067724        2.471233   0.795231
# MDB    0.003575  1.050986 -0.000836 -4.850432        2.471233   0.637852
# MDB    0.003114  0.931992 -0.002610 -5.292866        2.471233   0.541679
# MDB    0.002613  1.374267 -0.011722 -4.677473        2.471233   0.759103
# MDB    0.002781  1.299414 -0.003297 -5.901033        2.471233   0.638182
#
#        option_type_False  option_type_True  option_type_call  option_type_put
# stock
# AAPL               False              True              True            False
# AAPL               False              True              True            False
# AAPL               False              True              True            False
# AAPL               False              True              True            False
# AAPL               False              True              True            False
# ...                  ...               ...               ...              ...
# MDB                False              True             False             True
# MDB                False              True             False             True
# MDB                False              True             False             True
# MDB                False              True             False             True
# MDB                False              True             False             True
#
# [70662 rows x 21 columns]

# %%
df_encoded =df_encoded.dropna()

# %%
df_encoded.isna().sum()
# Out:
# lastTradeDate        0
# strike               0
# lastPrice            0
# change               0
# volume               0
# openInterest         0
# impliedVolatility    0
# expiration_date      0
# spot_price           0
# risk_free_rate       0
# Delta                0
# Gamma                0
# Vega                 0
# Theta                0
# Rho                  0
# time_to_expiry       0
# moneyness            0
# option_type_False    0
# option_type_True     0
# option_type_call     0
# option_type_put      0
# dtype: int64

# %%
final_cols = ["strike", "change","volume", "openInterest",	"impliedVolatility", 
              "time_to_expiry", "moneyness", "option_type_call", "option_type_put", "risk_free_rate", "Delta", "Gamma",
              "Vega", "Rho", "lastPrice", "spot_price"]
final_df = df_encoded[final_cols]
final_df
# Out:
#        strike    change  volume  openInterest  impliedVolatility  \
# stock
# AAPL    110.0  0.800003    40.0         418.0           1.593752
# AAPL    140.0  0.000000     3.0        1913.0           1.197270
# AAPL    145.0  0.000000    11.0          70.0           1.294925
# AAPL    150.0  0.000000    10.0          14.0           1.181645
# AAPL    155.0  0.000000     1.0           1.0           1.015630
# ...       ...       ...     ...           ...                ...
# MDB     260.0  0.000000     4.0           5.0           0.448431
# MDB     270.0  0.000000     4.0           4.0           0.401099
# MDB     280.0  0.000000    25.0          52.0           0.526433
# MDB     290.0  0.000000     1.0          26.0           0.439093
# MDB     330.0  1.600006     1.0           2.0           0.426336
#
#        time_to_expiry  moneyness  option_type_call  option_type_put  \
# stock
# AAPL         0.013699   1.839409              True            False
# AAPL         0.013699   1.435714              True            False
# AAPL         0.013699   1.386207              True            False
# AAPL         0.013699   1.340000              True            False
# AAPL         0.013699   1.296774              True            False
# ...               ...        ...               ...              ...
# MDB          2.471233   0.795231             False             True
# MDB          2.471233   0.637852             False             True
# MDB          2.471233   0.541679             False             True
# MDB          2.471233   0.759103             False             True
# MDB          2.471233   0.638182             False             True
#
#        risk_free_rate     Delta     Gamma      Vega       Rho  lastPrice  \
# stock
# AAPL           0.0419  0.999615  0.000037  0.000330  0.015049      91.80
# AAPL           0.0419  0.996035  0.000417  0.002765  0.019053      61.36
# AAPL           0.0419  0.987268  0.001079  0.007734  0.019482      53.74
# AAPL           0.0419  0.985719  0.001306  0.008540  0.020123      50.10
# AAPL           0.0419  0.987792  0.001327  0.007458  0.020870      43.55
# ...               ...       ...       ...       ...       ...        ...
# MDB            0.0419 -0.430803  0.002696  1.277127 -4.067724      91.73
# MDB            0.0419 -0.592368  0.003575  1.050986 -4.850432     123.35
# MDB            0.0419 -0.580014  0.003114  0.931992 -5.292866     141.19
# MDB            0.0419 -0.461822  0.002613  1.374267 -4.677473     106.25
# MDB            0.0419 -0.571635  0.002781  1.299414 -5.901033     141.25
#
#        spot_price
# stock
# AAPL   202.335007
# AAPL   201.000000
# AAPL   201.000000
# AAPL   201.000000
# AAPL   201.000000
# ...           ...
# MDB    206.759995
# MDB    172.220001
# MDB    151.669998
# MDB    220.139999
# MDB    210.600006
#
# [70662 rows x 16 columns]

# %%
put = final_df[final_df['option_type_put'] == True]
call = final_df[final_df['option_type_call'] == True]

# %%
call.isna().sum()
# Out:
# strike               0
# change               0
# volume               0
# openInterest         0
# impliedVolatility    0
# time_to_expiry       0
# moneyness            0
# option_type_call     0
# option_type_put      0
# risk_free_rate       0
# Delta                0
# Gamma                0
# Vega                 0
# Rho                  0
# lastPrice            0
# spot_price           0
# dtype: int64

# %% [markdown]
# # Models

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor

# %%
feature_cols =final_df.columns.difference(['lastPrice'])

# %%
X_train, X_test, y_train, y_test = train_test_split(call[feature_cols], call['lastPrice'], test_size = 0.2, random_state = 42)

skew_columns= ["impliedVolatility", 'Delta', 'Gamma', 'Vega', 'Rho']
for col in skew_columns:
    min_pos = X_train[col][X_train[col]>0].min()
    X_train[col] = X_train[col].replace(0, min_pos * 0.1)
    X_train[col] = X_train[col].apply(lambda x: min_pos * 0.1 if x <= 0 else x)
    X_train[col + '_log'] = np.log(X_train[col])
    X_test[col] = X_test[col].replace(0, min_pos * 0.1)
    X_test[col] = X_test[col].apply(lambda x: min_pos * 0.1 if x <= 0 else x)
    X_test[col + '_log'] = np.log(X_test[col])

    X_train.drop(col, axis=1)
    X_test.drop(col, axis=1)

print(X_train.dtypes)
X_train = X_train.select_dtypes(include=[np.number])
X_test = X_test.select_dtypes(include= [np.number])
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)


models = {
    "Linear Regression": LinearRegression(),
    "Random Forest" : RandomForestRegressor(n_estimators = 100, random_state = 42),
    "Gradient Boosting" : GradientBoostingRegressor(n_estimators = 100, random_state = 42),
    "XGBoost" : XGBRegressor(n_estimators= 100, random_state=42)
}

for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"{name} MSE: {mse}")
    print(f"{name} R-Squared: {r2}")
# Out:
# Delta                    float64
# Gamma                    float64
# Rho                      float64
# Vega                     float64
# change                   float64
# impliedVolatility        float64
# moneyness                float64
# openInterest             float64
# option_type_call            bool
# option_type_put             bool
# risk_free_rate           float64
# spot_price               float64
# strike                   float64
# time_to_expiry           float64
# volume                   float64
# impliedVolatility_log    float64
# Delta_log                float64
# Gamma_log                float64
# Vega_log                 float64
# Rho_log                  float64
# dtype: object
# Linear Regression MSE: 8280.403545035975
# Linear Regression R-Squared: 0.8339443973646992
# Random Forest MSE: 1756.3008627355262
# Random Forest R-Squared: 0.9647790597904755
# Gradient Boosting MSE: 3266.542065520998
# Gradient Boosting R-Squared: 0.9344926115891019
# XGBoost MSE: 2411.8420145892337
# XGBoost R-Squared: 0.9516328066602685

# %%
import matplotlib.pyplot as plt
def plot_residuals(actual, predicted, title):
    residuals = actual - predicted
    plt.figure(figsize=(10, 6))
    plt.scatter(predicted, residuals, alpha=0.5)
    plt.title(f'Residual Plot for {title}')
    plt.xlabel('Predicted Values')
    plt.ylabel('Residuals')
    plt.axhline(y=0, color='r', linestyle='-')
    plt.grid(True)
    plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.dummy import DummyRegressor


# Dictionary to store cross-validation results
cross_val_results = {}

for name, model in models.items():
    # Fit model and predict
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)

    # Residual plot
    plot_residuals(y_test, y_pred, name)

    # MSE and R-squared
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"{name} Mean Squared Error: {mse:.4f}")
    print(f"{name} R-Squared: {r2:.4f}")

    # Cross-validate MSE
    mse_scores = -cross_val_score(model, X_train_scaled, y_train, cv=5, scoring='neg_mean_squared_error')
    cross_val_results[name] = mse_scores
    print(f"Cross-validated MSE for {name}: {mse_scores.mean():.4f} (+/- {mse_scores.std():.4f})")
# Out:
# Linear Regression Mean Squared Error: 8280.4035
# Linear Regression R-Squared: 0.8339
# Cross-validated MSE for Linear Regression: 8883.2421 (+/- 713.8537)
# Random Forest Mean Squared Error: 1756.3009
# Random Forest R-Squared: 0.9648
# Cross-validated MSE for Random Forest: 315.4304 (+/- 69.9515)
# Gradient Boosting Mean Squared Error: 3266.5421
# Gradient Boosting R-Squared: 0.9345
# Cross-validated MSE for Gradient Boosting: 688.1792 (+/- 71.2658)
# XGBoost Mean Squared Error: 2411.8420
# XGBoost R-Squared: 0.9516
# Cross-validated MSE for XGBoost: 386.3586 (+/- 55.3495)
